# %%
# Импротируем необходимые функции
import numpy as np # работа с массивами и линейной алгеброй
import matplotlib.pyplot as plt # для отрисовки графиков
#import matplotlib as mpl
import matplotlib.ticker as ticker
#mpl.rcParams['font.size'] = 12 # Управление стилем, в данном случаем - размером шрифта 

def line(x, a, b):
    """
    Параметрическая прямая
    """
    return a*x + b

y1=np.array([-0.43,-3.63,-6.64,-9.64,-11.71,-10.32,-9.77,-8.64,-7.54,-7.20,-5.74,-4.49,-4.00,-2.49,-1.27,-0.95])
y2=np.array([-0.99,-5.04,-9.04,-12.12,-11.52,-10.87,-9.3,-8.67,-7.4,-6.84,-5.63,-4.47,-4.36,-2.74,-1.5,-1.52])
y3=np.array([-1.09,-6.32,-11.34,-12.19,-11.45,-10.55,-9.75,-8.7,-7.52,-6.93,-5.34,-4.8,-3.71,-2.25,-1.36,-1.36])
y4=np.array([-0.63,-2.64,-4.64,-6.64,-7.42,-5.22,-4.93,-1.1,0.43,2.64,4.65,6.65,8.65,0.43,0.43,14.65])
y5=np.array([-1.48,-5.52,-9.52,-9.36,-7.36,-5.49,-3.1,-0.99,0.78,2.72,4.7,6.35,8.7,10.72,0.43,14.72])
y6=np.array([-1.48,-5.52,-9.52,-9.36,-7.36,-5.49,-3.1,-0.99,0.78,2.72,4.7,6.35,8.7,10.72,0.43,14.72])

fig=plt.figure(figsize=(7,7))
ax = plt.subplot(111)

ax.set_title('Зависимость логарифма ошибки первой производной\n от логарифма шага для N=3')

for i in range (15):
    z = np.linspace(-i, -i-1, 1000)
    a=-y1[i+1]+y1[i]
    b=a*i+y1[i]
    ax.plot(z, line(z, a, b), 'b')

ax.grid(which = "major", linewidth = 1)
ax.grid(which = "minor", linewidth = 0.2)
ax.minorticks_on()
ax.set_xlabel(''r'$\log_{10}\,h$')
ax.set_ylabel(""r"$\log_{10}\,|f\,'(1)-e|$")

plt.show()
fig.savefig('First derivative N=3.png')

fig=plt.figure(figsize=(7,7))
ax = plt.subplot(111)

ax.set_title('Зависимость логарифма ошибки первой производной\n от логарифма шага для N=4')

for i in range (15):
    z = np.linspace(-i, -i-1, 1000)
    a=-y2[i+1]+y2[i]
    b=a*i+y2[i]
    ax.plot(z, line(z, a, b), 'b')

ax.grid(which = "major", linewidth = 1)
ax.grid(which = "minor", linewidth = 0.2)
ax.minorticks_on()
ax.set_xlabel(''r'$\log_{10}\,h$')
ax.set_ylabel(""r"$\log_{10}\,|f\,'(1)-e|$")


plt.show()
fig.savefig('First derivative N=4.png')

fig=plt.figure(figsize=(7,7))
ax = plt.subplot(111)

ax.set_title('Зависимость логарифма ошибки первой производной\n от логарифма шага для N=5')

for i in range (15):
    z = np.linspace(-i, -i-1, 1000)
    a=-y3[i+1]+y3[i]
    b=a*i+y3[i]
    ax.plot(z, line(z, a, b), 'b')

ax.grid(which = "major", linewidth = 1)
ax.grid(which = "minor", linewidth = 0.2)
ax.minorticks_on()
ax.set_xlabel(''r'$\log_{10}\,h$')
ax.set_ylabel(""r"$\log_{10}\,|f\,'(1)-e|$")


plt.show()
fig.savefig('First derivative N=5.png')

fig=plt.figure(figsize=(7,7))
ax = plt.subplot(111)

ax.set_title('Зависимость логарифма ошибки второй производной\n от логарифма шага для N=3')

for i in range (15):
    z = np.linspace(-i, -i-1, 1000)
    a=-y4[i+1]+y4[i]
    b=a*i+y4[i]
    ax.plot(z, line(z, a, b), 'b')

ax.grid(which = "major", linewidth = 1)
ax.grid(which = "minor", linewidth = 0.2)
ax.minorticks_on()
ax.set_xlabel(''r'$\log_{10}\,h$')
ax.set_ylabel(""r"$\log_{10}\,|f\,''(1)-e|$")

plt.show()
fig.savefig('Second derivative N=3.png')

fig=plt.figure(figsize=(7,7))
ax = plt.subplot(111)

ax.set_title('Зависимость логарифма ошибки второй производной\n от логарифма шага для N=4')

for i in range (15):
    z = np.linspace(-i, -i-1, 1000)
    a=-y5[i+1]+y5[i]
    b=a*i+y5[i]
    ax.plot(z, line(z, a, b), 'b')

ax.grid(which = "major", linewidth = 1)
ax.grid(which = "minor", linewidth = 0.2)
ax.minorticks_on()
ax.set_xlabel(''r'$\log_{10}\,h$')
ax.set_ylabel(""r"$\log_{10}\,|f\,''(1)-e|$")


plt.show()
fig.savefig('Second derivative N=4.png')

fig=plt.figure(figsize=(7,7))
ax = plt.subplot(111)

ax.set_title('Зависимость логарифма ошибки второй производной\n от логарифма шага для N=5')

for i in range (15):
    z = np.linspace(-i, -i-1, 1000)
    a=-y6[i+1]+y6[i]
    b=a*i+y6[i]
    ax.plot(z, line(z, a, b), 'b')

ax.grid(which = "major", linewidth = 1)
ax.grid(which = "minor", linewidth = 0.2)
ax.minorticks_on()
ax.set_xlabel(''r'$\log_{10}\,h$')
ax.set_ylabel(""r"$\log_{10}\,|f\,''(1)-e|$")


plt.show()
fig.savefig('Second derivative N=5.png')
